# %% [markdown]
# Attrition Prediction Exercise - Data Wrangling

# %% [markdown]
# This project is aimed at understanding what factors in an employee's current work environment could be influencing their decision to leave the company.
#
# In order to do this analysis, i will be bringing together:
#
# -- employee data available in the Human Capital Management (HCM) system - this includes the employee's job level, salary, compa-ratio (salary in comparison to mid point for that role in that location), gender etc.
#
# -- employee's performance data
#
# -- employee's reasons for leaving
#
# -- employee's response to the last engagement survey before they left the organization
#
# Please note: I have created and used a PII safe dataset. Because this information is based on my current organization, i am not uploading the data (even though it is PII safe) in the git repo.

# %%
#start by importing any libraries i might need
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (3.7.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: pandas>=0.25 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\m.bajaj\anaconda3\envs\capstone_attrition\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import datetime
from datetime import date
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#Next import all the csv files containing all the employee data we will need and will be merging 
#emp_df includes all data about employee from the Human Capital Management system including job level, salary, gender etc.
emp_df = pd.read_csv(r'C:\Users\m.bajaj\Python\Capstone2_Attrition\PII_safe_data\emp_data_no_pii.csv')
#perf_df includes data about employee's last recieved performance rating
perf_df = pd.read_csv(r'C:\Users\m.bajaj\Python\Capstone2_Attrition\PII_safe_data\perf_data_no_pii_use.csv')
#term_df includes additional data about termination like reason for leaving 
term_df = pd.read_csv(r'C:\Users\m.bajaj\Python\Capstone2_Attrition\PII_safe_data\term_data_no_pii.csv')
#engmt_df includes data from the last engagement survey taken by the employee. This spans over about 47 questions rated on a 5 point likert scale
engmt_df = pd.read_csv(r'C:\Users\m.bajaj\Python\Capstone2_Attrition\PII_safe_data\engmt_data_no_pii_use_final.csv')

# %%
# Start by looking at the emp_df dataset 
#emp_df.head()

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 32 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Title                                            543 non-null    object
#  1   Worker Type (regular, international, temporary)  543 non-null    object
#  2   Employment Type                                  543 non-null    object
#  3   Department                                       543 non-null    object
#  4   Work Location                                    543 non-null    object
#  5   Compensation (hourly wage or salary)             543 non-null    float64
#  6   Compensation type (hourly, salary)               543 non-null    object
#  7   Currency                                         543 non-null    object
#  8   Current Employment Start Date                    543 non-null    object
#  9   Initial Employment Start Date                    543 non-null    object
#  10  Termination Date                                 87 non-null     object
#  11  Status (Active / Terminated)                     543 non-null    object
#  12  Is FLSA Exempt?                                  543 non-null    bool
#  13  EEO Race                                         280 non-null    object
#  14  EEO Job Category                                 277 non-null    object
#  15  Job Level                                        543 non-null    object
#  16  Bonus Target                                     543 non-null    object
#  17  Worksite Designation                             543 non-null    object
#  18  Salary Structure                                 543 non-null    object
#  19  Salary Tier                                      543 non-null    object
#  20  Test CC                                          543 non-null    object
#  21  Job Code                                         538 non-null    object
#  22  City                                             535 non-null    object
#  23  State                                            525 non-null    object
#  24  Date of Birth                                    541 non-null    object
#  25  Age                                              541 non-null    float64
#  26  Gender                                           543 non-null    object
#  27  Comp Mid Point                                   528 non-null    object
#  28  Team Size                                        543 non-null    int64
#  29  Employee ID                                      543 non-null    int64
#  30  Manager ID                                       543 non-null    int64
#  31  Unnamed: 31                                      0 non-null      float64
# dtypes: bool(1), float64(3), int64(3), object(25)
# memory usage: 132.2+ KB

# %% [markdown]
# Notice in the above data that employee id is an integer, manager id is a float and date fields are objects. Need to rectify them. Will do this once i merge all data sets.

# %%
#count missing values by column
missing = pd.concat([emp_df.isna().sum(), 100 * emp_df.isna().mean()], axis = 1)
missing.columns = ['count', '%']
missing.sort_values(by = '%', ascending = False)
# Out:
#                                                  count           %
# Unnamed: 31                                        543  100.000000
# Termination Date                                   456   83.977901
# EEO Job Category                                   266   48.987109
# EEO Race                                           263   48.434622
# State                                               18    3.314917
# Comp Mid Point                                      15    2.762431
# City                                                 8    1.473297
# Job Code                                             5    0.920810
# Date of Birth                                        2    0.368324
# Age                                                  2    0.368324
# Salary Structure                                     0    0.000000
# Gender                                               0    0.000000
# Team Size                                            0    0.000000
# Employee ID                                          0    0.000000
# Manager ID                                           0    0.000000
# Test CC                                              0    0.000000
# Salary Tier                                          0    0.000000
# Title                                                0    0.000000
# Worksite Designation                                 0    0.000000
# Worker Type (regular, international, temporary)      0    0.000000
# Job Level                                            0    0.000000
# Is FLSA Exempt?                                      0    0.000000
# Status (Active / Terminated)                         0    0.000000
# Initial Employment Start Date                        0    0.000000
# Current Employment Start Date                        0    0.000000
# Currency                                             0    0.000000
# Compensation type (hourly, salary)                   0    0.000000
# Compensation (hourly wage or salary)                 0    0.000000
# Work Location                                        0    0.000000
# Department                                           0    0.000000
# Employment Type                                      0    0.000000
# Bonus Target                                         0    0.000000

# %% [markdown]
# EEEO Race and Job Category is missing a lot of values. This is because it is an optional data field for employees to fill. We will keep this as is for now
#
# Termination date is missing for a significant amount of people. This is actually correct because most employees in our file are active employees and only 87 are terminated which is why we have termination dates only for 87 employees
#
# City and State information is missing for a few people - this is because we have a few employees that are outside US and do not have this level of dat available. We will keep this as is for now
#
# Comp mid-point is missing for 15 people. All 15 people are part of the executive team and mid-point is not available for them.
#
# Lastly, in a prior iteration, it was realized that data was missing for FSLA status, Job ID etc. This was fixed in the raw data file and hence is not visible in version of data wrangling.

# %%
#Next we will review the data in our performance data frame
#perf_df.head()

# %%
perf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 3 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee ID              543 non-null    int64
#  1   Performance Rating Date  385 non-null    object
#  2   Performance Rating       384 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 12.9+ KB

# %% [markdown]
# We see that there are no missing values for performance rating and employee id columns so we are good to go ahead and merge this data with our emp_df dataframe.

# %%
#New we will merge emp_df with perf_df
emp_df = pd.merge(emp_df, perf_df, how = 'left', on = 'Employee ID')
#emp_df.head()

# %% [markdown]
# We reviewed the combined dataframe and it looked good. So we move to the next step i.e. reviewing and merging our next data frame called term_df

# %%
#Now we review our term dataframe
#term_df.head()

# %%
#Reviewing to see if we are missing any values on our term_df dataframe
missing_term = pd.concat([term_df.isna().sum(), 100* term_df.isna().mean()], axis = 1)
missing_term.columns = ['count', '%']
missing_term.sort_values(by = '%', ascending = False)
# Out:
#                               count          %
# Source                           72  80.898876
# Title or Role at New Company     49  55.056180
# Company Employee is going?       35  39.325843
# Termination Notes                22  24.719101
# Term Reason                       5   5.617978
# Tenure Months                     2   2.247191
# Tenure                            0   0.000000
# Term Type                         0   0.000000
# Employee ID                       0   0.000000

# %% [markdown]
# After the review, we saw term reason was missing for a few employees. We went back and fixed this in the raw data. Term reason for 5 employees is actually not available and we will keep it as is.
#
# We see that 'Title or Role at New Company' and 'Company Employee is going?' has a number of missing values. These fields do not appear to be critical to our analysis. We will merge the data frames and then drop these columns

# %%
#New merge term with emp dataframe
emp_df = pd.merge(emp_df, term_df, how = 'left', on = 'Employee ID')

# %%
emp_df = emp_df.drop(['Title or Role at New Company', 'Company Employee is going?', 'Tenure Months', 'Tenure'], axis = 1)

# %%
#emp_df.head()

# %%
#Next review engagement data
#engmt_df.head()

# %% [markdown]
# Initially, i had imported survey data only for the month of December 2022. However, on review it was realized that survey information was missing for a large number of people (300+). To overcome the issue, i then acquired data for the last survey taken by employees. This reduced the missing information greatly. This was however updated at the raw data stage.

# %%
# Next merge emp_df with engmt_df
emp_df = pd.merge(emp_df, engmt_df, how = 'left', on = 'Employee ID')
#emp_df.head()

# %%
#We now have a very big data set and most columns are hidden. Writing a code to unhide all hidden columns in between. This is particularly needed as we explore .info()
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#emp_df.head()

# %%
#count missing values by column
missing = pd.concat([emp_df.isna().sum(), 100 * emp_df.isna().mean()], axis = 1)
missing.columns = ['count', '%']
missing.sort_values(by = '%', ascending = False)
# Out:
#                                                     count           %
# Unnamed: 31                                           543  100.000000
# Source                                                527   97.053407
# Termination Notes                                     481   88.581952
# Term Reason                                           464   85.451197
# Term Type                                             459   84.530387
# Termination Date                                      456   83.977901
# EEO Job Category                                      266   48.987109
# EEO Race                                              263   48.434622
# Performance Rating                                    159   29.281768
# Performance Rating Date                               158   29.097606
# What can ORG do better to support you in workin...    158   29.097606
# What are some things we need to do better?            157   28.913444
# survey_date                                           153   28.176796
# My immediate manager keeps me informed about wh...    151   27.808471
# We have enough autonomy to perform our jobs eff...    151   27.808471
# Other departments at ORG collaborate well with ...    151   27.808471
# We are genuinely supported in balancing our wor...    151   27.808471
# My job performance is evaluated fairly                151   27.808471
# ORG really allows us to make a positive difference    151   27.808471
# We hold ourselves and our team members accounta...    151   27.808471
# I have been provided an opportunity to see and ...    151   27.808471
# ORG effectively directs resources (funding, peo...    151   27.808471
# I know what I need to do to be successful in my...    151   27.808471
# When I share an opinion, it is valued                 151   27.808471
# The executive leaders at ORG keep people inform...    151   27.808471
# ORG motivates me to go beyond what I would in a...    151   27.808471
# At ORG there is open and honest two-way communi...    151   27.808471
# I am proud to work for ORG                            151   27.808471
# ORG is in a position to really succeed over the...    151   27.808471
# Day-to-day decisions here demonstrate that qual...    151   27.808471
# My immediate manager keeps our team focused on ...    151   27.808471
# At ORG, we operate with integrity                     151   27.808471
# I believe there are good career opportunities f...    151   27.808471
# I see myself still working at ORG in two years'...    151   27.808471
# I am appropriately involved in decisions that a...    151   27.808471
# Our physical space is enjoyable to work in            151   27.808471
# My immediate manager genuinely cares about me a...    151   27.808471
# I feel I am part of a team                            151   27.808471
# The executive leaders at ORG have communicated ...    151   27.808471
# I believe my total compensation (base salary + ...    151   27.808471
# I rarely think about looking for a job at anoth...    151   27.808471
# I can be my authentic self at work                    151   27.808471
# I can work productively from my current location      151   27.808471
# We are encouraged to be innovative even though ...    151   27.808471
# I would recommend my immediate manager to others      151   27.808471
# Most of the systems and processes here support ...    151   27.808471
# The executive leaders at ORG demonstrate that p...    151   27.808471
# I have access to the learning and development I...    151   27.808471
# I can voice a contrary opinion without fear of ...    151   27.808471
# My immediate manager gives me useful feedback o...    151   27.808471
# Org Level                                             151   27.808471
# I know how my work contributes to the goals of ORG    151   27.808471
# I receive appropriate recognition for good work...    151   27.808471
# ORG's commitment to social responsibility (e.g....    151   27.808471
# We are genuinely supported if we choose to make...    151   27.808471
# I feel like I belong at ORG                           151   27.808471
# I have confidence in the executive leaders at ORG     151   27.808471
# I believe action will take place as a result of...    151   27.808471
# The information I need to do my job effectively...    151   27.808471
# The products and services ORG provides are as g...    151   27.808471
# I would recommend ORG as a great place to work        151   27.808471
# State                                                  18    3.314917
# Comp Mid Point                                         15    2.762431
# City                                                    8    1.473297
# Job Code                                                5    0.920810
# Age                                                     2    0.368324
# Date of Birth                                           2    0.368324
# Team Size                                               0    0.000000
# Is FLSA Exempt?                                         0    0.000000
# Employment Type                                         0    0.000000
# Department                                              0    0.000000
# Work Location                                           0    0.000000
# Compensation (hourly wage or salary)                    0    0.000000
# Compensation type (hourly, salary)                      0    0.000000
# Currency                                                0    0.000000
# Current Employment Start Date                           0    0.000000
# Initial Employment Start Date                           0    0.000000
# Status (Active / Terminated)                            0    0.000000
# Bonus Target                                            0    0.000000
# Job Level                                               0    0.000000
# Employee ID                                             0    0.000000
# Worksite Designation                                    0    0.000000
# Salary Structure                                        0    0.000000
# Salary Tier                                             0    0.000000
# Test CC                                                 0    0.000000
# Worker Type (regular, international, temporary)         0    0.000000
# Manager ID                                              0    0.000000
# Gender                                                  0    0.000000
# Title                                                   0    0.000000

# %% [markdown]
# We see the fields identified earlier i.e. EEO job category etc are still the same in terms of missing values. As decided, we will not do anything with these fieldss at this stage. Also, there is little scope to acquire this information.
#
# Performance rating and survey data is missing for about 150+ employees. However, this is a lot less than wheat we had initially. As mentioned, the larger number of missing values were fixed by taking the last performance rating and last survey taken for all employees. No more action can be taken at this point and this information is relevant and we would like to retain it at this point to better understand attrition.

# %%
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 0 to 542
# Data columns (total 89 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Title                                                                                                                       543 non-null    object
#  1   Worker Type (regular, international, temporary)                                                                             543 non-null    object
#  2   Employment Type                                                                                                             543 non-null    object
#  3   Department                                                                                                                  543 non-null    object
#  4   Work Location                                                                                                               543 non-null    object
#  5   Compensation (hourly wage or salary)                                                                                        543 non-null    float64
#  6   Compensation type (hourly, salary)                                                                                          543 non-null    object
#  7   Currency                                                                                                                    543 non-null    object
#  8   Current Employment Start Date                                                                                               543 non-null    object
#  9   Initial Employment Start Date                                                                                               543 non-null    object
#  10  Termination Date                                                                                                            87 non-null     object
#  11  Status (Active / Terminated)                                                                                                543 non-null    object
#  12  Is FLSA Exempt?                                                                                                             543 non-null    bool
#  13  EEO Race                                                                                                                    280 non-null    object
#  14  EEO Job Category                                                                                                            277 non-null    object
#  15  Job Level                                                                                                                   543 non-null    object
#  16  Bonus Target                                                                                                                543 non-null    object
#  17  Worksite Designation                                                                                                        543 non-null    object
#  18  Salary Structure                                                                                                            543 non-null    object
#  19  Salary Tier                                                                                                                 543 non-null    object
#  20  Test CC                                                                                                                     543 non-null    object
#  21  Job Code                                                                                                                    538 non-null    object
#  22  City                                                                                                                        535 non-null    object
#  23  State                                                                                                                       525 non-null    object
#  24  Date of Birth                                                                                                               541 non-null    object
#  25  Age                                                                                                                         541 non-null    float64
#  26  Gender                                                                                                                      543 non-null    object
#  27  Comp Mid Point                                                                                                              528 non-null    object
#  28  Team Size                                                                                                                   543 non-null    int64
#  29  Employee ID                                                                                                                 543 non-null    int64
#  30  Manager ID                                                                                                                  543 non-null    int64
#  31  Unnamed: 31                                                                                                                 0 non-null      float64
#  32  Performance Rating Date                                                                                                     385 non-null    object
#  33  Performance Rating                                                                                                          384 non-null    object
#  34  Term Type                                                                                                                   84 non-null     object
#  35  Term Reason                                                                                                                 79 non-null     object
#  36  Termination Notes                                                                                                           62 non-null     object
#  37  Source                                                                                                                      16 non-null     object
#  38  survey_date                                                                                                                 390 non-null    object
#  39  I would recommend ORG as a great place to work                                                                              392 non-null    float64
#  40  The products and services ORG provides are as good as, or better than, our main competitors                                 392 non-null    float64
#  41  The information I need to do my job effectively is readily available                                                        392 non-null    float64
#  42  I believe action will take place as a result of this survey                                                                 392 non-null    float64
#  43  I have confidence in the executive leaders at ORG                                                                           392 non-null    float64
#  44  Other departments at ORG collaborate well with us to get the job done                                                       392 non-null    float64
#  45  We are genuinely supported if we choose to make use of flexible working arrangements                                        392 non-null    float64
#  46  ORG's commitment to social responsibility (e.g. community support, sustainability, etc.) is genuine                         392 non-null    float64
#  47  I receive appropriate recognition for good work at ORG                                                                      392 non-null    float64
#  48  I feel like I belong at ORG                                                                                                 392 non-null    float64
#  49  I know how my work contributes to the goals of ORG                                                                          392 non-null    float64
#  50  Day-to-day decisions here demonstrate that quality and improvement are top priorities                                       392 non-null    float64
#  51  My immediate manager gives me useful feedback on how well I am performing                                                   392 non-null    float64
#  52  ORG motivates me to go beyond what I would in a similar role elsewhere                                                      392 non-null    float64
#  53  The executive leaders at ORG keep people informed about what is happening                                                   392 non-null    float64
#  54  When I share an opinion, it is valued                                                                                       392 non-null    float64
#  55  I know what I need to do to be successful in my role                                                                        392 non-null    float64
#  56  ORG effectively directs resources (funding, people and effort) towards company goals                                        392 non-null    float64
#  57  I have been provided an opportunity to see and discuss recent employee survey results                                       392 non-null    float64
#  58  What are some things we need to do better?                                                                                  386 non-null    object
#  59  We hold ourselves and our team members accountable for results                                                              392 non-null    float64
#  60  ORG really allows us to make a positive difference                                                                          392 non-null    float64
#  61  My job performance is evaluated fairly                                                                                      392 non-null    float64
#  62  We have enough autonomy to perform our jobs effectively                                                                     392 non-null    float64
#  63  My immediate manager keeps me informed about what is happening at ORG                                                       392 non-null    float64
#  64  At ORG there is open and honest two-way communication                                                                       392 non-null    float64
#  65  We are genuinely supported in balancing our work and life needs                                                             392 non-null    float64
#  66  ORG is in a position to really succeed over the next three years                                                            392 non-null    float64
#  67  I am proud to work for ORG                                                                                                  392 non-null    float64
#  68  I can voice a contrary opinion without fear of negative consequences                                                        392 non-null    float64
#  69  I have access to the learning and development I need to do my job well                                                      392 non-null    float64
#  70  The executive leaders at ORG demonstrate that people are important to the company's success                                 392 non-null    float64
#  71  What can ORG do better to support you in working productively?                                                              385 non-null    object
#  72  Most of the systems and processes here support us getting our work done effectively                                         392 non-null    float64
#  73  I would recommend my immediate manager to others                                                                            392 non-null    float64
#  74  We are encouraged to be innovative even though some of our initiatives may not succeed                                      392 non-null    float64
#  75  I can work productively from my current location                                                                            392 non-null    float64
#  76  I can be my authentic self at work                                                                                          392 non-null    float64
#  77  I rarely think about looking for a job at another company                                                                   392 non-null    float64
#  78  I believe my total compensation (base salary + any bonuses + equity) is fair, relative to similar roles at other companies  392 non-null    float64
#  79  The executive leaders at ORG have communicated a vision that motivates me                                                   392 non-null    float64
#  80  I feel I am part of a team                                                                                                  392 non-null    float64
#  81  My immediate manager genuinely cares about me as a person                                                                   392 non-null    float64
#  82  Our physical space is enjoyable to work in                                                                                  392 non-null    float64
#  83  I am appropriately involved in decisions that affect my work                                                                392 non-null    float64
#  84  I see myself still working at ORG in two years' time                                                                        392 non-null    float64
#  85  I believe there are good career opportunities for me at ORG                                                                 392 non-null    float64
#  86  At ORG, we operate with integrity                                                                                           392 non-null    float64
#  87  My immediate manager keeps our team focused on clear priorities                                                             392 non-null    float64
#  88  Org Level                                                                                                                   392 non-null    object
# dtypes: bool(1), float64(50), int64(3), object(35)
# memory usage: 378.1+ KB

# %% [markdown]
# We notice most date fields are 'objects', 'comp Mid Point' is an object and 'Manager Id' is a float. We will work on fixing these data types next.

# %%
#change all date fields to datetime dtype and manager id to an integer
emp_df [['Current Employment Start Date', 'Initial Employment Start Date', 'Termination Date', 'Date of Birth', 'Performance Rating Date', 'survey_date']] = emp_df [['Current Employment Start Date', 'Initial Employment Start Date', 'Termination Date', 'Date of Birth', 'Performance Rating Date', 'survey_date']].apply(pd.to_datetime)
emp_df['Manager ID'] = emp_df['Manager ID'].astype(int, errors='ignore')
emp_df['Comp Mid Point'] = pd.to_numeric(emp_df['Comp Mid Point'], errors = 'coerce')
emp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 543 entries, 0 to 542
# Data columns (total 89 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Title                                                                                                                       543 non-null    object
#  1   Worker Type (regular, international, temporary)                                                                             543 non-null    object
#  2   Employment Type                                                                                                             543 non-null    object
#  3   Department                                                                                                                  543 non-null    object
#  4   Work Location                                                                                                               543 non-null    object
#  5   Compensation (hourly wage or salary)                                                                                        543 non-null    float64
#  6   Compensation type (hourly, salary)                                                                                          543 non-null    object
#  7   Currency                                                                                                                    543 non-null    object
#  8   Current Employment Start Date                                                                                               543 non-null    datetime64[ns]
#  9   Initial Employment Start Date                                                                                               543 non-null    datetime64[ns]
#  10  Termination Date                                                                                                            87 non-null     datetime64[ns]
#  11  Status (Active / Terminated)                                                                                                543 non-null    object
#  12  Is FLSA Exempt?                                                                                                             543 non-null    bool
#  13  EEO Race                                                                                                                    280 non-null    object
#  14  EEO Job Category                                                                                                            277 non-null    object
#  15  Job Level                                                                                                                   543 non-null    object
#  16  Bonus Target                                                                                                                543 non-null    object
#  17  Worksite Designation                                                                                                        543 non-null    object
#  18  Salary Structure                                                                                                            543 non-null    object
#  19  Salary Tier                                                                                                                 543 non-null    object
#  20  Test CC                                                                                                                     543 non-null    object
#  21  Job Code                                                                                                                    538 non-null    object
#  22  City                                                                                                                        535 non-null    object
#  23  State                                                                                                                       525 non-null    object
#  24  Date of Birth                                                                                                               541 non-null    datetime64[ns]
#  25  Age                                                                                                                         541 non-null    float64
#  26  Gender                                                                                                                      543 non-null    object
#  27  Comp Mid Point                                                                                                              522 non-null    float64
#  28  Team Size                                                                                                                   543 non-null    int64
#  29  Employee ID                                                                                                                 543 non-null    int64
#  30  Manager ID                                                                                                                  543 non-null    int32
#  31  Unnamed: 31                                                                                                                 0 non-null      float64
#  32  Performance Rating Date                                                                                                     385 non-null    datetime64[ns]
#  33  Performance Rating                                                                                                          384 non-null    object
#  34  Term Type                                                                                                                   84 non-null     object
#  35  Term Reason                                                                                                                 79 non-null     object
#  36  Termination Notes                                                                                                           62 non-null     object
#  37  Source                                                                                                                      16 non-null     object
#  38  survey_date                                                                                                                 390 non-null    datetime64[ns]
#  39  I would recommend ORG as a great place to work                                                                              392 non-null    float64
#  40  The products and services ORG provides are as good as, or better than, our main competitors                                 392 non-null    float64
#  41  The information I need to do my job effectively is readily available                                                        392 non-null    float64
#  42  I believe action will take place as a result of this survey                                                                 392 non-null    float64
#  43  I have confidence in the executive leaders at ORG                                                                           392 non-null    float64
#  44  Other departments at ORG collaborate well with us to get the job done                                                       392 non-null    float64
#  45  We are genuinely supported if we choose to make use of flexible working arrangements                                        392 non-null    float64
#  46  ORG's commitment to social responsibility (e.g. community support, sustainability, etc.) is genuine                         392 non-null    float64
#  47  I receive appropriate recognition for good work at ORG                                                                      392 non-null    float64
#  48  I feel like I belong at ORG                                                                                                 392 non-null    float64
#  49  I know how my work contributes to the goals of ORG                                                                          392 non-null    float64
#  50  Day-to-day decisions here demonstrate that quality and improvement are top priorities                                       392 non-null    float64
#  51  My immediate manager gives me useful feedback on how well I am performing                                                   392 non-null    float64
#  52  ORG motivates me to go beyond what I would in a similar role elsewhere                                                      392 non-null    float64
#  53  The executive leaders at ORG keep people informed about what is happening                                                   392 non-null    float64
#  54  When I share an opinion, it is valued                                                                                       392 non-null    float64
#  55  I know what I need to do to be successful in my role                                                                        392 non-null    float64
#  56  ORG effectively directs resources (funding, people and effort) towards company goals                                        392 non-null    float64
#  57  I have been provided an opportunity to see and discuss recent employee survey results                                       392 non-null    float64
#  58  What are some things we need to do better?                                                                                  386 non-null    object
#  59  We hold ourselves and our team members accountable for results                                                              392 non-null    float64
#  60  ORG really allows us to make a positive difference                                                                          392 non-null    float64
#  61  My job performance is evaluated fairly                                                                                      392 non-null    float64
#  62  We have enough autonomy to perform our jobs effectively                                                                     392 non-null    float64
#  63  My immediate manager keeps me informed about what is happening at ORG                                                       392 non-null    float64
#  64  At ORG there is open and honest two-way communication                                                                       392 non-null    float64
#  65  We are genuinely supported in balancing our work and life needs                                                             392 non-null    float64
#  66  ORG is in a position to really succeed over the next three years                                                            392 non-null    float64
#  67  I am proud to work for ORG                                                                                                  392 non-null    float64
#  68  I can voice a contrary opinion without fear of negative consequences                                                        392 non-null    float64
#  69  I have access to the learning and development I need to do my job well                                                      392 non-null    float64
#  70  The executive leaders at ORG demonstrate that people are important to the company's success                                 392 non-null    float64
#  71  What can ORG do better to support you in working productively?                                                              385 non-null    object
#  72  Most of the systems and processes here support us getting our work done effectively                                         392 non-null    float64
#  73  I would recommend my immediate manager to others                                                                            392 non-null    float64
#  74  We are encouraged to be innovative even though some of our initiatives may not succeed                                      392 non-null    float64
#  75  I can work productively from my current location                                                                            392 non-null    float64
#  76  I can be my authentic self at work                                                                                          392 non-null    float64
#  77  I rarely think about looking for a job at another company                                                                   392 non-null    float64
#  78  I believe my total compensation (base salary + any bonuses + equity) is fair, relative to similar roles at other companies  392 non-null    float64
#  79  The executive leaders at ORG have communicated a vision that motivates me                                                   392 non-null    float64
#  80  I feel I am part of a team                                                                                                  392 non-null    float64
#  81  My immediate manager genuinely cares about me as a person                                                                   392 non-null    float64
#  82  Our physical space is enjoyable to work in                                                                                  392 non-null    float64
#  83  I am appropriately involved in decisions that affect my work                                                                392 non-null    float64
#  84  I see myself still working at ORG in two years' time                                                                        392 non-null    float64
#  85  I believe there are good career opportunities for me at ORG                                                                 392 non-null    float64
#  86  At ORG, we operate with integrity                                                                                           392 non-null    float64
#  87  My immediate manager keeps our team focused on clear priorities                                                             392 non-null    float64
#  88  Org Level                                                                                                                   392 non-null    object
# dtypes: bool(1), datetime64[ns](6), float64(51), int32(1), int64(2), object(28)
# memory usage: 376.0+ KB

# %% [markdown]
# As a next step, we also need to do some calculations which will be helpful in our analysis
#
# First we, need to make sure that we have annual salary for all employees. Current salary column shows annual salary for those with annual salary but only an hourly amount for the hourly paid employees.
#
# Next, since we want to do a survival curve analysis to predict attrition, we need to calcular tenure. We will calculate tenure in weeks, given most people have been at the organization of interest for less than a year.
#
# Finally, we want to see how are people being paid in comparison to market. We will compare people's salary to market mid-point and create a field called 'compa-ratio-%'

# %%
#First, we will calculate annual compensation. We need to use two different attributes to calculate this field. 
#One attribute telling us whether someone's salary is hourly, and 
#Second attribute being compensation amount

#emp_df['annual_salary'] = emp_df['Compensation (hourly wage or salary)']
#emp_df['annual_salary'][emp_df['Compensation type (hourly, salary)'] == 'H'] = emp_df['Compensation (hourly wage or salary)'][emp_df['Compensation type (hourly, salary)'] == 'H']*2080
#emp_df

emp_df['annual_salary'] = np.where(emp_df['Compensation type (hourly, salary)'] == 'H',emp_df['Compensation (hourly wage or salary)'] * 2080, 
                                   emp_df['Compensation (hourly wage or salary)'])

# %% [markdown]
# Next, we want to calculate tenure. For this we first need to add today's date as a new column and make sure the new column is datetime data type

# %%
#Add a column with today's date to calculate tenure
emp_df['todays date']= datetime.today().strftime('%Y-%m-%d')
emp_df['todays date'] = pd.to_datetime(emp_df['todays date'])

# %%
print(emp_df.dtypes)
# Out:
# Title                                                                                                                                 object
# Worker Type (regular, international, temporary)                                                                                       object
# Employment Type                                                                                                                       object
# Department                                                                                                                            object
# Work Location                                                                                                                         object
# Compensation (hourly wage or salary)                                                                                                 float64
# Compensation type (hourly, salary)                                                                                                    object
# Currency                                                                                                                              object
# Current Employment Start Date                                                                                                 datetime64[ns]
# Initial Employment Start Date                                                                                                 datetime64[ns]
# Termination Date                                                                                                              datetime64[ns]
# Status (Active / Terminated)                                                                                                          object
# Is FLSA Exempt?                                                                                                                         bool
# EEO Race                                                                                                                              object
# EEO Job Category                                                                                                                      object
# Job Level                                                                                                                             object
# Bonus Target                                                                                                                          object
# Worksite Designation                                                                                                                  object
# Salary Structure                                                                                                                      object
# Salary Tier                                                                                                                           object
# Test CC                                                                                                                               object
# Job Code                                                                                                                              object
# City                                                                                                                                  object
# State                                                                                                                                 object
# Date of Birth                                                                                                                 datetime64[ns]
# Age                                                                                                                                  float64
# Gender                                                                                                                                object
# Comp Mid Point                                                                                                                       float64
# Team Size                                                                                                                              int64
# Employee ID                                                                                                                            int64
# Manager ID                                                                                                                             int32
# Unnamed: 31                                                                                                                          float64
# Performance Rating Date                                                                                                       datetime64[ns]
# Performance Rating                                                                                                                    object
# Term Type                                                                                                                             object
# Term Reason                                                                                                                           object
# Termination Notes                                                                                                                     object
# Source                                                                                                                                object
# survey_date                                                                                                                   datetime64[ns]
# I would recommend ORG as a great place to work                                                                                       float64
# The products and services ORG provides are as good as, or better than, our main competitors                                          float64
# The information I need to do my job effectively is readily available                                                                 float64
# I believe action will take place as a result of this survey                                                                          float64
# I have confidence in the executive leaders at ORG                                                                                    float64
# Other departments at ORG collaborate well with us to get the job done                                                                float64
# We are genuinely supported if we choose to make use of flexible working arrangements                                                 float64
# ORG's commitment to social responsibility (e.g. community support, sustainability, etc.) is genuine                                  float64
# I receive appropriate recognition for good work at ORG                                                                               float64
# I feel like I belong at ORG                                                                                                          float64
# I know how my work contributes to the goals of ORG                                                                                   float64
# Day-to-day decisions here demonstrate that quality and improvement are top priorities                                                float64
# My immediate manager gives me useful feedback on how well I am performing                                                            float64
# ORG motivates me to go beyond what I would in a similar role elsewhere                                                               float64
# The executive leaders at ORG keep people informed about what is happening                                                            float64
# When I share an opinion, it is valued                                                                                                float64
# I know what I need to do to be successful in my role                                                                                 float64
# ORG effectively directs resources (funding, people and effort) towards company goals                                                 float64
# I have been provided an opportunity to see and discuss recent employee survey results                                                float64
# What are some things we need to do better?                                                                                            object
# We hold ourselves and our team members accountable for results                                                                       float64
# ORG really allows us to make a positive difference                                                                                   float64
# My job performance is evaluated fairly                                                                                               float64
# We have enough autonomy to perform our jobs effectively                                                                              float64
# My immediate manager keeps me informed about what is happening at ORG                                                                float64
# At ORG there is open and honest two-way communication                                                                                float64
# We are genuinely supported in balancing our work and life needs                                                                      float64
# ORG is in a position to really succeed over the next three years                                                                     float64
# I am proud to work for ORG                                                                                                           float64
# I can voice a contrary opinion without fear of negative consequences                                                                 float64
# I have access to the learning and development I need to do my job well                                                               float64
# The executive leaders at ORG demonstrate that people are important to the company's success                                          float64
# What can ORG do better to support you in working productively?                                                                        object
# Most of the systems and processes here support us getting our work done effectively                                                  float64
# I would recommend my immediate manager to others                                                                                     float64
# We are encouraged to be innovative even though some of our initiatives may not succeed                                               float64
# I can work productively from my current location                                                                                     float64
# I can be my authentic self at work                                                                                                   float64
# I rarely think about looking for a job at another company                                                                            float64
# I believe my total compensation (base salary + any bonuses + equity) is fair, relative to similar roles at other companies           float64
# The executive leaders at ORG have communicated a vision that motivates me                                                            float64
# I feel I am part of a team                                                                                                           float64
# My immediate manager genuinely cares about me as a person                                                                            float64
# Our physical space is enjoyable to work in                                                                                           float64
# I am appropriately involved in decisions that affect my work                                                                         float64
# I see myself still working at ORG in two years' time                                                                                 float64
# I believe there are good career opportunities for me at ORG                                                                          float64
# At ORG, we operate with integrity                                                                                                    float64
# My immediate manager keeps our team focused on clear priorities                                                                      float64
# Org Level                                                                                                                             object
# annual_salary                                                                                                                        float64
# todays date                                                                                                                   datetime64[ns]
# dtype: object

# %% [markdown]
# Now we will calculate tenure. However, in our dataframe we have both active and terminated employees. For all active employees we can calculate tenure by subtracting today's date from their hire date.
#
# However, for terminated employees, we need to calculate tenure by subtracting their termination date from their hire date.
#
# I used the np.where() function to derive this value

# %%
#Use the np.where() function to calculate tenure in weeks
emp_df['Tenure_weeks'] = np.where(emp_df['Status (Active / Terminated)'] == 'Active', 
                                  (emp_df['todays date'] - emp_df['Current Employment Start Date'])/np.timedelta64(1,'W'), 
                                  (emp_df['Termination Date'] - emp_df['Current Employment Start Date']) /np.timedelta64(1, 'W'))
#emp_df.head()

# %% [markdown]
# Next, we calculate the compa-ratio in percentage which is how does one's annual salary compare with the market mid point for that role in that given location.

# %%
#Compa ratio is merely a ratio between the annual salary and market mid-point and can be calculated by:
#dividing annual salary by comp mid point.  
#Additionally, we will also multiply this number by 100 so we get a percentage
emp_df['compa-ratio-%'] = (emp_df['annual_salary']/emp_df['Comp Mid Point'])*100
#emp_df.head()

# %%
#reviewing the data ranges for numerical data types
#emp_df.describe()

# %% [markdown]
# We do not see any anomolies in the distribution of the data at the moment.
#
# Employee and Manager ID show up as a float although they are not. However, we will not change this at this point.
#
# Lastly, we will export this data as a comma separated values (csv) file and and this new file will become our final dataset for futher steps in the analysis

# %%
#temporary pull of the file
emp_df.to_csv(r'C:\Users\m.bajaj\Python\Git_hub_repos\attrition-prediction\PII_safe_data\emp_df_merged.csv', index = False)
